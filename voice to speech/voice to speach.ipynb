# %%
# !pip install pyttsx3
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
# ...

# %%
# !pip install gtts
# Out:
# ...
#
#   Attempting uninstall: click
#
#     Found existing installation: click 8.5.0
#
#     Uninstalling click-8.5.0:
#
#       Successfully uninstalled click-8.5.0
#
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    -------------------- ------------------- 1/2 [gtts]
#    -------------------- ------------------- 1/2 [gtts]
#    -------------------- ------------------- 1/2 [gtts]
#    -------------------- ------------------- 1/2 [gtts]
#    -------------------- ------------------- 1/2 [gtts]
# ...

# %%
# !pip install playsound

# %%
import tkinter as tk
from tkinter import *
from tkinter import filedialog #making windows for selected files
from tkinter.ttk import Combobox #combined an entry feild and list
import pyttsx3
import os 
from gtts import gTTS
from playsound import playsound
